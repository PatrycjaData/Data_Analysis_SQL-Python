# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
results=pd.read_csv('Results_Number_of_cities_per_country.csv')
results
# Out:
#                country  Number_of_cities
# 0            Argentina                13
# 1               Brazil                28
# 2               Canada                 7
# 3                China                53
# 4             Colombia                 6
# 5                Egypt                 6
# 6              Germany                 7
# 7                India                60
# 8            Indonesia                14
# 9                 Iran                 8
# 10               Italy                 7
# 11               Japan                31
# 12              Mexico                30
# 13         Netherlands                 5
# 14             Nigeria                13
# 15            Pakistan                 5
# 16         Philippines                20
# 17              Poland                 8
# 18  Russian Federation                28
# 19        Saudi Arabia                 5
# 20        South Africa                11
# 21         South Korea                 5
# ...

# %%
results.plot(kind = 'barh',
            title = 'Number_of_cities_per_country',
            color = '#4CAF50',
            legend=False)
plt.xlabel('Number of Cities')
plt.ylabel('Country')
plt.show()
